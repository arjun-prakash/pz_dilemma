# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../')

# %%
from pettingzoo.classic import rpsls_v1
from src.environments import dilemma_v0
import supersuit as ss
from pettingzoo.utils.conversions import to_parallel

# %%
from stable_baselines3.common.monitor import Monitor

# %%
env = dilemma_v0.env(game='sd')
#env = rpsls_v1.env()


#env = ss.agent_indicator_v0(env)

# %%
from pettingzoo.utils import random_demo
random_demo(env)
# Out:
# Current state: Agent1: None , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# ...
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 3, 'player_1': 4}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: SOCIAL
# {'player_0': 2, 'player_1': 2}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Average total reward 5088.0
# 5088

# %%
env = to_parallel(env)

env = ss.pettingzoo_env_to_vec_env_v0(env)
env = ss.concat_vec_envs_v0(env, 1, base_class='stable_baselines3')

# %%
from stable_baselines3.common.monitor import Monitor

# %%
from stable_baselines3 import A2C

model = A2C('MlpPolicy', 
            env, 
            verbose=3,
            tensorboard_log='tmp/')
model.learn(total_timesteps=2000000)
model.save("policy")
# Out:
# Using cpu device
# Logging to tmp/A2C_14
# ------------------------------------
# | time/                 |          |
# |    fps                | 1888     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | -0.0122  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 6.91     |
# |    value_loss         | 119      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1909     |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | -0.00631 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 4.08     |
# |    value_loss         | 36.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1915     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0.0029   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 5.5      |
# |    value_loss         | 90.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1707      |
# |    iterations         | 400       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.687    |
# |    explained_variance | -0.000835 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 4.67      |
# |    value_loss         | 59.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1615      |
# |    iterations         | 500       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.635    |
# |    explained_variance | -4.65e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 5.61      |
# |    value_loss         | 106       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1537     |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.615   |
# |    explained_variance | 0.000401 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 3.33     |
# |    value_loss         | 80.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1462     |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.644   |
# |    explained_variance | 0.000273 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 5.36     |
# |    value_loss         | 75.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1367     |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.352   |
# |    explained_variance | 0.000107 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 7.53     |
# |    value_loss         | 81.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1389      |
# |    iterations         | 900       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.513    |
# |    explained_variance | -4.37e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.96      |
# |    value_loss         | 87.7      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1427     |
# |    iterations         | 1000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.387   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.2      |
# |    value_loss         | 93.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1460     |
# |    iterations         | 1100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.284   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.73     |
# |    value_loss         | 90.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1465     |
# |    iterations         | 1200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.323   |
# |    explained_variance | 8.83e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 2.55     |
# |    value_loss         | 68.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1487      |
# |    iterations         | 1300      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.432    |
# |    explained_variance | -9.54e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 6.13      |
# |    value_loss         | 82.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1496     |
# |    iterations         | 1400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.437   |
# |    explained_variance | 1.73e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 2.31     |
# |    value_loss         | 80.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1496      |
# |    iterations         | 1500      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.493    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 2.16      |
# |    value_loss         | 78.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1508     |
# |    iterations         | 1600     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.453   |
# |    explained_variance | 1.23e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 2.29     |
# |    value_loss         | 75.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1522     |
# |    iterations         | 1700     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.296   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.704    |
# |    value_loss         | 75       |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1524      |
# |    iterations         | 1800      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.434    |
# |    explained_variance | -0.000106 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.97      |
# |    value_loss         | 40.4      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1523     |
# |    iterations         | 1900     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.488   |
# |    explained_variance | 1.14e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 3.87     |
# |    value_loss         | 67.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1540      |
# |    iterations         | 2000      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.393    |
# |    explained_variance | -1.37e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 2.75      |
# |    value_loss         | 54.7      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1559     |
# |    iterations         | 2100     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.368   |
# |    explained_variance | 5.5e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 1.14     |
# |    value_loss         | 30       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1578     |
# |    iterations         | 2200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.416   |
# |    explained_variance | 3.62e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 3.98     |
# |    value_loss         | 61.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1594     |
# |    iterations         | 2300     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.276   |
# |    explained_variance | 4.09e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 2.05     |
# |    value_loss         | 44.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1606     |
# |    iterations         | 2400     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.416   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 1.07     |
# |    value_loss         | 58.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1622      |
# |    iterations         | 2500      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.252    |
# |    explained_variance | -5.66e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 2.91      |
# |    value_loss         | 55.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1635      |
# |    iterations         | 2600      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.23     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.41      |
# |    value_loss         | 54.1      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1646     |
# |    iterations         | 2700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.288   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.557    |
# |    value_loss         | 52       |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1653      |
# |    iterations         | 2800      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.155    |
# |    explained_variance | -2.55e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 2.64      |
# |    value_loss         | 48.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1659      |
# |    iterations         | 2900      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.252    |
# |    explained_variance | -0.000113 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 0.438     |
# |    value_loss         | 48        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1659     |
# |    iterations         | 3000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.163   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.234    |
# |    value_loss         | 46       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1659     |
# |    iterations         | 3100     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.0504  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.0516   |
# |    value_loss         | 44.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1653     |
# |    iterations         | 3200     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.0303  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0273   |
# |    value_loss         | 42.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1645     |
# |    iterations         | 3300     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.078   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0844   |
# |    value_loss         | 40.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1631     |
# |    iterations         | 3400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.147    |
# |    value_loss         | 38.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1622     |
# |    iterations         | 3500     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.11    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.124    |
# |    value_loss         | 36.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1615     |
# |    iterations         | 3600     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.161   |
# |    explained_variance | -0.00013 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.2      |
# |    value_loss         | 35.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1599     |
# |    iterations         | 3700     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.178   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.223    |
# |    value_loss         | 33.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1571     |
# |    iterations         | 3800     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.112   |
# |    explained_variance | 7.38e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.946    |
# |    value_loss         | 19       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1561     |
# |    iterations         | 3900     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.198   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.244    |
# |    value_loss         | 30.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1570     |
# |    iterations         | 4000     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.15    |
# |    explained_variance | 8.59e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.831    |
# |    value_loss         | 16.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1572     |
# |    iterations         | 4100     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.19    |
# |    explained_variance | 1.22e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 1.46     |
# |    value_loss         | 25.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1581     |
# |    iterations         | 4200     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.241    |
# |    value_loss         | 25.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1588      |
# |    iterations         | 4300      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -0.361    |
# |    explained_variance | -4.05e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.49      |
# |    value_loss         | 23.1      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1596     |
# |    iterations         | 4400     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.289   |
# |    explained_variance | 6.6e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.674    |
# |    value_loss         | 12.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1604     |
# |    iterations         | 4500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.316   |
# |    explained_variance | 5.2e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.654    |
# |    value_loss         | 11.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1612     |
# |    iterations         | 4600     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.21    |
# |    explained_variance | 5.78e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 1.17     |
# |    value_loss         | 18.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1620      |
# |    iterations         | 4700      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -0.155    |
# |    explained_variance | -4.28e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.44      |
# |    value_loss         | 18        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1625      |
# |    iterations         | 4800      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -0.158    |
# |    explained_variance | -0.000145 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 1.68      |
# |    value_loss         | 3.32      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1631     |
# |    iterations         | 4900     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -0.262   |
# |    explained_variance | 2.78e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.848    |
# |    value_loss         | 15.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1636     |
# |    iterations         | 5000     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.269   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.261    |
# |    value_loss         | 15.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1642     |
# |    iterations         | 5100     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 51000    |
# | train/                |          |
# |    entropy_loss       | -0.181   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.144    |
# |    value_loss         | 14.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1648      |
# |    iterations         | 5200      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 52000     |
# | train/                |           |
# |    entropy_loss       | -0.346    |
# |    explained_variance | -4.54e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 0.998     |
# |    value_loss         | 12.5      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1654     |
# |    iterations         | 5300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 53000    |
# | train/                |          |
# |    entropy_loss       | -0.242   |
# |    explained_variance | -3.1e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.225   |
# |    value_loss         | 3.34     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1657     |
# |    iterations         | 5400     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.167   |
# |    explained_variance | 3.05e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 1.26     |
# |    value_loss         | 7.2      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1661     |
# |    iterations         | 5500     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 55000    |
# | train/                |          |
# |    entropy_loss       | -0.118   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0674   |
# |    value_loss         | 11.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1665     |
# |    iterations         | 5600     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.132   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0743   |
# |    value_loss         | 10.3     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1670      |
# |    iterations         | 5700      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 57000     |
# | train/                |           |
# |    entropy_loss       | -0.0682   |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | 0.0304    |
# |    value_loss         | 9.53      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1658     |
# |    iterations         | 5800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.0365  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0134   |
# |    value_loss         | 8.77     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1641     |
# |    iterations         | 5900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 59000    |
# | train/                |          |
# |    entropy_loss       | -0.0603  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0232   |
# |    value_loss         | 8.07     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1622     |
# |    iterations         | 6000     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.0545  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0192   |
# |    value_loss         | 7.4      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1618     |
# |    iterations         | 6100     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 61000    |
# | train/                |          |
# |    entropy_loss       | -0.0922  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0344   |
# |    value_loss         | 6.79     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1615     |
# |    iterations         | 6200     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.0493  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.0147   |
# |    value_loss         | 6.21     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1610     |
# |    iterations         | 6300     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 63000    |
# | train/                |          |
# |    entropy_loss       | -0.0872  |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.0274   |
# |    value_loss         | 5.68     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1614     |
# |    iterations         | 6400     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.0285  |
# |    explained_variance | 5.9e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.0064   |
# |    value_loss         | 5.19     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1619     |
# |    iterations         | 6500     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 65000    |
# | train/                |          |
# |    entropy_loss       | -0.0205  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00395  |
# |    value_loss         | 4.75     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1624     |
# |    iterations         | 6600     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.0111  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.00175  |
# |    value_loss         | 4.36     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1624     |
# |    iterations         | 6700     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 67000    |
# | train/                |          |
# |    entropy_loss       | -0.0103  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.00143  |
# |    value_loss         | 4        |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1626     |
# |    iterations         | 6800     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.00758 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.000875 |
# |    value_loss         | 3.69     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1626      |
# |    iterations         | 6900      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 69000     |
# | train/                |           |
# |    entropy_loss       | -2.76e-11 |
# |    explained_variance | -0.000177 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -21.3     |
# |    value_loss         | 1.97      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1630      |
# |    iterations         | 7000      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 70000     |
# | train/                |           |
# |    entropy_loss       | -4.7e-16  |
# |    explained_variance | -0.000342 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -25.7     |
# |    value_loss         | 1.76      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1634      |
# |    iterations         | 7100      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 71000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0        |
# |    value_loss         | 43.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1637      |
# |    iterations         | 7200      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 72000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 3.58e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.34e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1640      |
# |    iterations         | 7300      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 73000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 5.54e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -0        |
# |    value_loss         | 5.89e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1642      |
# |    iterations         | 7400      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 74000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 2.5e-06   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.1e-05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1643      |
# |    iterations         | 7500      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 75000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 6.32e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0        |
# |    value_loss         | 3.31e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1641      |
# |    iterations         | 7600      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 76000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 2.44e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.19e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1640      |
# |    iterations         | 7700      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 77000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0        |
# |    value_loss         | 0.000421  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1640      |
# |    iterations         | 7800      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 78000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -0        |
# |    value_loss         | 0.00014   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1640      |
# |    iterations         | 7900      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 79000     |
# | train/                |           |
# |    entropy_loss       | -3.16e-16 |
# |    explained_variance | 2.32e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -0        |
# |    value_loss         | 2.17e-05  |
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-e326d2ea4958> in <module>
#       5             verbose=3,
#       6             tensorboard_log='tmp/')
# ----> 7 model.learn(total_timesteps=2000000)
#       8 model.save("policy")
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     188     ) -> "A2C":
#     189
# --> 190         return super(A2C, self).learn(
#     191             total_timesteps=total_timesteps,
#     192             callback=callback,
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     225         while self.num_timesteps < total_timesteps:
#     226
# --> 227             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     228
#     229             if continue_training is False:
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     157                 # Convert to pytorch tensor
#     158                 obs_tensor = th.as_tensor(self._last_obs).to(self.device)
# --> 159                 actions, values, log_probs = self.policy.forward(obs_tensor)
#     160             actions = actions.cpu().numpy()
#     161
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/policies.py in forward(self, obs, deterministic)
#     532         :return: action, value and log probability of the action
#     533         """
# --> 534         latent_pi, latent_vf, latent_sde = self._get_latent(obs)
#     535         # Evaluate the values for the given observations
#     536         values = self.value_net(latent_vf)
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/policies.py in _get_latent(self, obs)
#     551         # Preprocess the observation if needed
#     552         features = self.extract_features(obs)
# --> 553         latent_pi, latent_vf = self.mlp_extractor(features)
#     554
#     555         # Features for sde
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/torch_layers.py in forward(self, features)
#     222         """
#     223         shared_latent = self.shared_net(features)
# --> 224         return self.policy_net(shared_latent), self.value_net(shared_latent)
#     225
#     226
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# KeyboardInterrupt:

# %%
env = dilemma_v0.env('sd')

#env = ss.agent_indicator_v0(env)
rewards = []
env.reset()
for agent in env.agent_iter():
    obs, reward, done, info = env.last()
    rewards.append(reward)
    act = model.predict(obs)[0] if not done else None
    env.step(act)
    env.render()
# Out:
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# ...
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}

# %%
import sys
sys.path.append('../')

from pettingzoo.test import parallel_api_test
from src.environments import simple_pd_v0

env = dilemma_v0.env()
env = to_parallel(env)

parallel_api_test(env, num_cycles=1)

# %%
env = dilemma_v0.env('sd')

#env = ss.agent_indicator_v0(env)
rewards = []
env.reset()

# %%
obs, reward, done, info = env.last()
print(obs, reward, done, info)
rewards.append(reward)
act = model.predict(0)[0] if not done else None
env.step(act)
env.render()
# Out:
# 0 4 False {}
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
