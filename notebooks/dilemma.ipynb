# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# %%
import sys
sys.path.append('../')

# %%
from pettingzoo.classic import rpsls_v1
from src.environments import dilemma_v0
import supersuit as ss
from pettingzoo.utils.conversions import to_parallel

# %%
from stable_baselines3.common.monitor import Monitor

# %%
env = dilemma_v0.env(game='pd')
#env = rpsls_v1.env()


#env = ss.agent_indicator_v0(env)

# %%
from pettingzoo.utils import random_demo
random_demo(env)
# Out:
# Current state: Agent1: None , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# ...
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: COOPERATE
# {'player_0': 3, 'player_1': 3}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: DEFECT
# {'player_0': 1, 'player_1': 1}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Current state: Agent1: DEFECT , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: DEFECT , Agent2: COOPERATE
# {'player_0': 5, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: COOPERATE , Agent2: DEFECT
# {'player_0': 0, 'player_1': 5}
#
# Average total reward 4517.0
# 4517

# %%
env = to_parallel(env)

env = ss.pettingzoo_env_to_vec_env_v0(env)
env = ss.concat_vec_envs_v0(env, 1, base_class='stable_baselines3')

# %%
from stable_baselines3.common.monitor import Monitor

# %%
from stable_baselines3 import A2C

model = A2C('MlpPolicy', 
            env, 
            verbose=3,
            ent_coef=0.12,
            tensorboard_log='tmp/')
model.learn(total_timesteps=2000000)
model.save("policy")
# Out:
# Using cpu device
# Logging to tmp/A2C_8
# ------------------------------------
# | time/                 |          |
# |    fps                | 625      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -0.00775 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 5.08     |
# |    value_loss         | 75       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 959      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -0.00645 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 6.14     |
# |    value_loss         | 89.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1081     |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | -0.00199 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 4.58     |
# |    value_loss         | 56       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1224     |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.00101 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 4.11     |
# |    value_loss         | 52.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1188      |
# |    iterations         | 500       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.669    |
# |    explained_variance | -0.000922 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 5.13      |
# |    value_loss         | 84.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1203     |
# |    iterations         | 600      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | 0.000507 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 5.62     |
# |    value_loss         | 89       |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-360508d43ee1> in <module>
#       6             ent_coef=0.12,
#       7             tensorboard_log='tmp/')
# ----> 8 model.learn(total_timesteps=2000000)
#       9 model.save("policy")
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     188     ) -> "A2C":
#     189
# --> 190         return super(A2C, self).learn(
#     191             total_timesteps=total_timesteps,
#     192             callback=callback,
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     245                 logger.dump(step=self.num_timesteps)
#     246
# --> 247             self.train()
#     248
#     249         callback.on_training_end()
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/a2c/a2c.py in train(self)
#     158             # Optimization step
#     159             self.policy.optimizer.zero_grad()
# --> 160             loss.backward()
#     161
#     162             # Clip grad norm
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
env = dilemma_v0.env('sd')

#env = ss.agent_indicator_v0(env)
rewards = []
env.reset()
for agent in env.agent_iter():
    obs, reward, done, info = env.last()
    rewards.append(reward)
    act = model.predict(obs)[0] if not done else None
    env.step(act)
    env.render()
# Out:
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# ...
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}
#
# Current state: Agent1: SOCIAL , Agent2: None
# {'player_0': 0, 'player_1': 0}
#
# Current state: Agent1: SOCIAL , Agent2: SOCIAL
# {'player_0': 4, 'player_1': 3}

# %%
import sys
sys.path.append('../')

from pettingzoo.test import parallel_api_test
from src.environments import simple_pd_v0

env = dilemma_v0.env()
env = to_parallel(env)

parallel_api_test(env, num_cycles=1)

# %%
env = dilemma_v0.env('sd')

#env = ss.agent_indicator_v0(env)
rewards = []
env.reset()

# %%
obs, reward, done, info = env.last()
print(obs, reward, done, info)
rewards.append(reward)
act = model.predict(2)[0] if not done else None
env.step(1)
env.render()
# Out:
# 1 1 False {}
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}
