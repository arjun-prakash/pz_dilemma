# %%
import sys
sys.path.append('../')

# %%
from pettingzoo.classic import rps_v1
from src.environments import simple_pd_v0
import supersuit as ss
from pettingzoo.utils.conversions import to_parallel

# %%
#env = simple_pd_v0.env()
env = rps_v1.env()

env = ss.agent_indicator_v0(env)

# %%
random_demo?

# %%
from pettingzoo.utils import random_demo
random_demo(env)
# Out:
# Current state: Agent1: None , Agent2: None
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: SCISSORS
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: SCISSORS
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: SCISSORS
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: PAPER
# Current state: Agent1: PAPER , Agent2: None
# Current state: Agent1: PAPER , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: PAPER
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: ROCK
# Current state: Agent1: ROCK , Agent2: None
# Current state: Agent1: ROCK , Agent2: ROCK
# Current state: Agent1: SCISSORS , Agent2: None
# Current state: Agent1: SCISSORS , Agent2: PAPER
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-3e6a05319b63> in <module>
#       1 from pettingzoo.utils import random_demo
# ----> 2 random_demo(env)
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/random_demo.py in random_demo(env, render, episodes)
#      16         for agent in env.agent_iter():
#      17             if render:
# ---> 18                 env.render()
#      19
#      20             obs, reward, done, _ = env.last()
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/order_enforcing.py in render(self, mode)
#      43         assert mode in self.metadata['render.modes']
#      44         self._has_rendered = True
# ---> 45         return super().render(mode)
#      46
#      47     def step(self, action):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/order_enforcing.py in render(self, mode)
#      43         assert mode in self.metadata['render.modes']
#      44         self._has_rendered = True
# ---> 45         return super().render(mode)
#      46
#      47     def step(self, action):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/capture_stdout.py in render(self, mode)
#      10     def render(self, mode="human"):
#      11         if mode == "human":
# ---> 12             super().render()
#      13         elif mode == "ansi":
#      14             with capture_stdout() as stdout:
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/classic/rps/rps.py in render(self, mode)
#      50
#      51     def render(self, mode="human"):
# ---> 52         string = ("Current state: Agent1: {} , Agent2: {}".format(MOVES[self.state[self.agents[0]]], MOVES[self.state[self.agents[1]]]))
#      53         print(string)
#      54         return string
#
# IndexError: list index out of range

# %%
#env = ss.pad_action_space_v0(env)
#env = ss.pad_observations_v0(env)
#ebv = ss.normalize_obs_v0(env)
env = to_parallel(env)

env = ss.pettingzoo_env_to_vec_env_v0(env)

env = ss.concat_vec_envs_v0(env, 2, num_cpus=2, base_class='stable_baselines3')

#env = ss.concat_vec_envs_v0(env, 8, num_cpus=4, base_class='stable_baselines3')

# %%
import supersuit

# %%
from stable_baselines3 import PPO

# %%
model = PPO('MlpPolicy', env, verbose=3, gamma=0.99, n_steps=125, ent_coef=0.01, learning_rate=0.00025, vf_coef=0.5, max_grad_norm=0.5, gae_lambda=0.95, n_epochs=4, clip_range=0.2, clip_range_vf=1)
model.learn(total_timesteps=2000000)
model.save("policy")
# Out:
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    fps             | 3801     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 500      |
# | train/             |          |
# |    learning_rate   | 0.00025  |
# ---------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3155         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1000         |
# | train/                  |              |
# |    approx_kl            | 3.692269e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 1            |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00876     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.01         |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 5.88         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2965         |
# |    iterations           | 3            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 1500         |
# | train/                  |              |
# |    approx_kl            | 0.0017133371 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 1            |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.011       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.23         |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.0211      |
# |    value_loss           | 3.95         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2810        |
# |    iterations           | 4           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2000        |
# | train/                  |             |
# |    approx_kl            | 0.012330168 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0151      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.89        |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 3.6         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2712        |
# |    iterations           | 5           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 2500        |
# | train/                  |             |
# |    approx_kl            | 0.024287779 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0687     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.49        |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 3.64        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2609        |
# |    iterations           | 6           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 3000        |
# | train/                  |             |
# |    approx_kl            | 0.020952841 |
# |    clip_fraction        | 0.483       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0157      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.32        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2610        |
# |    iterations           | 7           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 3500        |
# | train/                  |             |
# |    approx_kl            | 0.032714516 |
# |    clip_fraction        | 0.6         |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.8         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 5.99        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2595       |
# |    iterations           | 8          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 4000       |
# | train/                  |            |
# |    approx_kl            | 0.05284863 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | -0.0514    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.22       |
# |    n_updates            | 28         |
# |    policy_gradient_loss | -0.0175    |
# |    value_loss           | 7.28       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2531       |
# |    iterations           | 9          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 4500       |
# | train/                  |            |
# |    approx_kl            | 0.03526146 |
# |    clip_fraction        | 0.599      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.0133     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.99       |
# |    n_updates            | 32         |
# |    policy_gradient_loss | -0.0232    |
# |    value_loss           | 4.61       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2488        |
# |    iterations           | 10          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.062080666 |
# |    clip_fraction        | 0.564       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0292      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.7         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 5.12        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2509       |
# |    iterations           | 11         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 5500       |
# | train/                  |            |
# |    approx_kl            | 0.05124607 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -0.0444    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.67       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 5.32       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2513       |
# |    iterations           | 12         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 6000       |
# | train/                  |            |
# |    approx_kl            | 0.04761968 |
# |    clip_fraction        | 0.648      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -0.0167    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.52       |
# |    n_updates            | 44         |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 4.12       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2532        |
# |    iterations           | 13          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6500        |
# | train/                  |             |
# |    approx_kl            | 0.047763914 |
# |    clip_fraction        | 0.609       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.27        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 8.9         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2533       |
# |    iterations           | 14         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 7000       |
# | train/                  |            |
# |    approx_kl            | 0.04155273 |
# |    clip_fraction        | 0.657      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.0814     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.45       |
# |    n_updates            | 52         |
# |    policy_gradient_loss | -0.0202    |
# |    value_loss           | 3.23       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2532        |
# |    iterations           | 15          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 7500        |
# | train/                  |             |
# |    approx_kl            | 0.061269924 |
# |    clip_fraction        | 0.609       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.071       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.34        |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 6.01        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2531        |
# |    iterations           | 16          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.059696298 |
# |    clip_fraction        | 0.604       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.68        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00461     |
# |    value_loss           | 6.3         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2533        |
# |    iterations           | 17          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8500        |
# | train/                  |             |
# |    approx_kl            | 0.061332382 |
# |    clip_fraction        | 0.6         |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 1           |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0851     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.72        |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 3.47        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2548       |
# |    iterations           | 18         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 9000       |
# | train/                  |            |
# |    approx_kl            | 0.07223434 |
# |    clip_fraction        | 0.63       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.231      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.983      |
# |    n_updates            | 68         |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 2.71       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2553       |
# |    iterations           | 19         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 9500       |
# | train/                  |            |
# |    approx_kl            | 0.05817804 |
# |    clip_fraction        | 0.64       |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 1          |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.0211    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.56       |
# |    n_updates            | 72         |
# |    policy_gradient_loss | -0.00963   |
# |    value_loss           | 3.07       |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-b8376b29df94> in <module>
#       1 model = PPO('MlpPolicy', env, verbose=3, gamma=0.99, n_steps=125, ent_coef=0.01, learning_rate=0.00025, vf_coef=0.5, max_grad_norm=0.5, gae_lambda=0.95, n_epochs=4, clip_range=0.2, clip_range_vf=1)
# ----> 2 model.learn(total_timesteps=2000000)
#       3 model.save("policy")
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     278     ) -> "PPO":
#     279
# --> 280         return super(PPO, self).learn(
#     281             total_timesteps=total_timesteps,
#     282             callback=callback,
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     245                 logger.dump(step=self.num_timesteps)
#     246
# --> 247             self.train()
#     248
#     249         callback.on_training_end()
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in train(self)
#     234                 # Optimization step
#     235                 self.policy.optimizer.zero_grad()
# --> 236                 loss.backward()
#     237                 # Clip grad norm
#     238                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
env = rps_v1.env()

env = ss.agent_indicator_v0(env)

env.reset()
for agent in env.agent_iter():
    obs, reward, done, info = env.last()
    print(obs)
    act = model.predict(obs)[0] if not done else None
    env.step(act)
    env.render()
# Out:
# 3
# Current state: Agent1: PAPER , Agent2: None
# 3
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: ROCK
# 0
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: PAPER
# 1
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: ROCK , Agent2: None
# 1
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: ROCK
# 0
# Current state: Agent1: SCISSORS , Agent2: None
# 2
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 0
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 2
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: PAPER
# 1
# Current state: Agent1: ROCK , Agent2: None
# 0
# Current state: Agent1: ROCK , Agent2: SCISSORS
# 2
# Current state: Agent1: PAPER , Agent2: None
# 0
# Current state: Agent1: PAPER , Agent2: ROCK
# 0
# Current state: Agent1: PAPER , Agent2: None
# 1
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: PAPER
# 1
# Current state: Agent1: PAPER , Agent2: None
# 2
# Current state: Agent1: PAPER , Agent2: SCISSORS
# 2
# Current state: Agent1: SCISSORS , Agent2: None
# 1
# Current state: Agent1: SCISSORS , Agent2: SCISSORS
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-df7fa4ed98f8> in <module>
#       9     act = model.predict(obs)[0] if not done else None
#      10     env.step(act)
# ---> 11     env.render()
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/order_enforcing.py in render(self, mode)
#      43         assert mode in self.metadata['render.modes']
#      44         self._has_rendered = True
# ---> 45         return super().render(mode)
#      46
#      47     def step(self, action):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/capture_stdout.py in render(self, mode)
#      10     def render(self, mode="human"):
#      11         if mode == "human":
# ---> 12             super().render()
#      13         elif mode == "ansi":
#      14             with capture_stdout() as stdout:
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py in render(self, mode)
#      47
#      48     def render(self, mode='human'):
# ---> 49         return self.env.render(mode)
#      50
#      51     def reset(self):
#
# ~/anaconda3/envs/rlenv/lib/python3.8/site-packages/pettingzoo/classic/rps/rps.py in render(self, mode)
#      50
#      51     def render(self, mode="human"):
# ---> 52         string = ("Current state: Agent1: {} , Agent2: {}".format(MOVES[self.state[self.agents[0]]], MOVES[self.state[self.agents[1]]]))
#      53         print(string)
#      54         return string
#
# IndexError: list index out of range

# %%
dir(env)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_all_attributes',
#  '_get_indices',
#  'action_space',
#  'close',
#  'env_is_wrapped',
#  'env_method',
#  'get_attr',
#  'get_images',
#  'getattr_depth_check',
#  'getattr_recursive',
#  'metadata',
#  'num_envs',
#  'observation_space',
#  'render',
#  'reset',
#  'seed',
#  'set_attr',
#  'step',
#  'step_async',
#  'step_wait',
#  'unwrapped',
#  'venv']
