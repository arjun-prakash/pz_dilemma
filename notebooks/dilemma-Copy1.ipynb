# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../')

# %%
from pettingzoo.classic import rpsls_v1
from src.environments import dilemma_v0
import supersuit as ss
from pettingzoo.utils.conversions import to_parallel

# %%
from stable_baselines3.common.monitor import Monitor

# %%
env = dilemma_v0.env(game='pd')
#env = rpsls_v1.env()


#env = ss.agent_indicator_v0(env)
# Out:
# Delimma v2
# {'player_0': Box(-1, 1, (1, 4), int8), 'player_1': Box(-1, 1, (1, 4), int8), 'player_2': Box(-1, 1, (1, 4), int8), 'player_3': Box(-1, 1, (1, 4), int8)}

# %%
from pettingzoo.utils import random_demo
random_demo(env)
# Out:
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 0, 'player_1': 0, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 5, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 0, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 5, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 5, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_3, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 1}
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, COOPERATE
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_0, COOPERATE
# Current moves: player_1 : COOPERATE, player_3, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_3, COOPERATE
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_1, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_1, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# ...
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 5, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : COOPERATE, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 5, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 0, 'player_1': 0, 'player_2': 5, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 0, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 0, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 0, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 1, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, DEFECT
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_1, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 3, 'player_1': 5, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 5, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : COOPERATE, player_1, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, COOPERATE
# rewards {'player_0': 3, 'player_1': 1, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 5, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 0, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_1, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 3, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 3}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_3, COOPERATE
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 3, 'player_2': 0, 'player_3': 1}
#
# Average total reward 35036.0
# 35036

# %%
env = dilemma_v0.env(game='pd')

env = to_parallel(env)

env = ss.pettingzoo_env_to_vec_env_v0(env)
env = ss.concat_vec_envs_v0(env, 1, base_class='stable_baselines3')
# Out:
# Delimma v2
# {'player_0': Box(-1, 1, (1, 4), int8), 'player_1': Box(-1, 1, (1, 4), int8), 'player_2': Box(-1, 1, (1, 4), int8), 'player_3': Box(-1, 1, (1, 4), int8)}

# %%
# %debug
# Out:
# > /home/arjun/anaconda3/envs/rlenv/lib/python3.8/site-packages/torch/nn/functional.py(1753)linear()
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# ipdb> q

# %%
from stable_baselines3.common.monitor import Monitor

# %%
from stable_baselines3 import A2C

model = A2C('MlpPolicy', 
            env, 
            verbose=3,
            ent_coef=0.12,
            tensorboard_log='tmp/')
model.learn(total_timesteps=2000000)
model.save("policy")
# Out:
# Using cpu device
# Logging to tmp/A2C_4
# ------------------------------------
# | time/                 |          |
# |    fps                | 2789     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.94    |
# |    explained_variance | 0.00249  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 41.4     |
# |    value_loss         | 541      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2886     |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.87    |
# |    explained_variance | 0.0794   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 48.4     |
# |    value_loss         | 955      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2970     |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | -1.38    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 35.1     |
# |    value_loss         | 825      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3021     |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -2.01    |
# |    explained_variance | 0.000947 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 33.3     |
# |    value_loss         | 583      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3047     |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.81    |
# |    explained_variance | 0.00183  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 50       |
# |    value_loss         | 781      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3070     |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.92    |
# |    explained_variance | 0.000722 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 66.4     |
# |    value_loss         | 2.03e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3085     |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.93    |
# |    explained_variance | 0.00194  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 55.2     |
# |    value_loss         | 854      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3097     |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.98    |
# |    explained_variance | 0.0071   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 89.6     |
# |    value_loss         | 2.36e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3099     |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.71    |
# |    explained_variance | 0.0159   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 58.6     |
# |    value_loss         | 1.92e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3098     |
# |    iterations         | 1000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.68    |
# |    explained_variance | 7.75e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 30.8     |
# |    value_loss         | 500      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3101     |
# |    iterations         | 1100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.89    |
# |    explained_variance | 0.128    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 35.9     |
# |    value_loss         | 636      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3100     |
# |    iterations         | 1200     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.96    |
# |    explained_variance | 0.0309   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 53.9     |
# |    value_loss         | 820      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3097     |
# |    iterations         | 1300     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.99    |
# |    explained_variance | 0.00589  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 41       |
# |    value_loss         | 694      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3094     |
# |    iterations         | 1400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.85    |
# |    explained_variance | 0.00521  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 22.6     |
# |    value_loss         | 384      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3088     |
# |    iterations         | 1500     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.92    |
# |    explained_variance | 0.014    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 64.4     |
# |    value_loss         | 1.4e+03  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3087     |
# |    iterations         | 1600     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.67    |
# |    explained_variance | -0.00949 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 30.2     |
# |    value_loss         | 512      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3084     |
# |    iterations         | 1700     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -2.01    |
# |    explained_variance | 0.04     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 34.7     |
# |    value_loss         | 466      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3083     |
# |    iterations         | 1800     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -1.98    |
# |    explained_variance | 0.000927 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 47.6     |
# |    value_loss         | 741      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3082      |
# |    iterations         | 1900      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.93     |
# |    explained_variance | -0.000107 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 50.9      |
# |    value_loss         | 860       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3081     |
# |    iterations         | 2000     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.95    |
# |    explained_variance | 0.00992  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 31.5     |
# |    value_loss         | 451      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3079     |
# |    iterations         | 2100     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -1.69    |
# |    explained_variance | -0.0148  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 32.6     |
# |    value_loss         | 851      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3078     |
# |    iterations         | 2200     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.67    |
# |    explained_variance | 0.0281   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 50.1     |
# |    value_loss         | 1.41e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3077      |
# |    iterations         | 2300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -1.64     |
# |    explained_variance | -0.000695 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 64.3      |
# |    value_loss         | 1.91e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3077     |
# |    iterations         | 2400     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 9.83e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 9.91     |
# |    value_loss         | 123      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3075     |
# |    iterations         | 2500     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | 0.00143  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 53       |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3074      |
# |    iterations         | 2600      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 52000     |
# | train/                |           |
# |    entropy_loss       | -1.81     |
# |    explained_variance | -0.000155 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 60.6      |
# |    value_loss         | 1.37e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3073     |
# |    iterations         | 2700     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 6.72e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 44.9     |
# |    value_loss         | 1.27e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3073     |
# |    iterations         | 2800     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.97    |
# |    explained_variance | -6.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 66.3     |
# |    value_loss         | 2.25e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3072      |
# |    iterations         | 2900      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 58000     |
# | train/                |           |
# |    entropy_loss       | -1.58     |
# |    explained_variance | -7.75e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 12.5      |
# |    value_loss         | 181       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3072     |
# |    iterations         | 3000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | -0.0177  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 21.3     |
# |    value_loss         | 311      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3071     |
# |    iterations         | 3100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | -0.114   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 79.5     |
# |    value_loss         | 2.45e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3070     |
# |    iterations         | 3200     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.000705 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 46.3     |
# |    value_loss         | 918      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3070     |
# |    iterations         | 3300     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.00359  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 34.6     |
# |    value_loss         | 1.04e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3069     |
# |    iterations         | 3400     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 0.0495   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 19.4     |
# |    value_loss         | 475      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3068     |
# |    iterations         | 3500     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.959   |
# |    explained_variance | -0.00278 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 9.08     |
# |    value_loss         | 94.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3068     |
# |    iterations         | 3600     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | 0.0278   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 24.2     |
# |    value_loss         | 230      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3068      |
# |    iterations         | 3700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 74000     |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | -0.000132 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 52.4      |
# |    value_loss         | 1.35e+03  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3068     |
# |    iterations         | 3800     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -2.01    |
# |    explained_variance | -0.0164  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 37.8     |
# |    value_loss         | 596      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3067     |
# |    iterations         | 3900     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -1.7     |
# |    explained_variance | 0.015    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 46.1     |
# |    value_loss         | 1.22e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3067     |
# |    iterations         | 4000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.0695   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 18.2     |
# |    value_loss         | 264      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3067     |
# |    iterations         | 4100     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | -0.0584  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 23.7     |
# |    value_loss         | 311      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3066     |
# |    iterations         | 4200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -1.85    |
# |    explained_variance | -0.00247 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 18.5     |
# |    value_loss         | 147      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3066     |
# |    iterations         | 4300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -1.81    |
# |    explained_variance | -3.51    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 21.1     |
# |    value_loss         | 165      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3066     |
# |    iterations         | 4400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -1.92    |
# |    explained_variance | 0.00117  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 40.3     |
# |    value_loss         | 568      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3066     |
# |    iterations         | 4500     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | 0.00571  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 24.8     |
# |    value_loss         | 313      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 4600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -1.9     |
# |    explained_variance | 0.07     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -16.4    |
# |    value_loss         | 107      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 4700     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -1.9     |
# |    explained_variance | 0.104    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 33.1     |
# |    value_loss         | 529      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 4800     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | -0.00151 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 23.3     |
# |    value_loss         | 321      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 4900     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -1.63    |
# |    explained_variance | 0.055    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 16.3     |
# |    value_loss         | 114      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3065      |
# |    iterations         | 5000      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | -0.000284 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 18.1      |
# |    value_loss         | 215       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 5100     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -0.184   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 21.1     |
# |    value_loss         | 197      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 5200     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 0.000404 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 9.87     |
# |    value_loss         | 79       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 5300     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.000602 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 9.05     |
# |    value_loss         | 61.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 5400     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.00187  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 8.45     |
# |    value_loss         | 59.2     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3064      |
# |    iterations         | 5500      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 110000    |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 7.25      |
# |    value_loss         | 58.3      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 5600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.00445  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 8.63     |
# |    value_loss         | 56.3     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3065      |
# |    iterations         | 5700      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 114000    |
# | train/                |           |
# |    entropy_loss       | -1.15     |
# |    explained_variance | -0.000681 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | 6.43      |
# |    value_loss         | 55.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 5800     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -1.62    |
# |    explained_variance | -0.0673  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 29.6     |
# |    value_loss         | 390      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 5900     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.097    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 3.89     |
# |    value_loss         | 49.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.00276 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 11.2     |
# |    value_loss         | 117      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6100     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | -3.1e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 6.11     |
# |    value_loss         | 47.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6200     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | -0.0298  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 46       |
# |    value_loss         | 1.12e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6300     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 0.745    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 9.98     |
# |    value_loss         | 95.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6400     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.00961  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 7.8      |
# |    value_loss         | 42.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.0269   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 7.55     |
# |    value_loss         | 41       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 6600     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | -0.00315 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 14.2     |
# |    value_loss         | 223      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 6700     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -1.96    |
# |    explained_variance | -0.00186 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 41.1     |
# |    value_loss         | 628      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6800     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.000909 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 11.1     |
# |    value_loss         | 139      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 6900     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.00141  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 4.53     |
# |    value_loss         | 36.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3065     |
# |    iterations         | 7000     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.52     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 2.36     |
# |    value_loss         | 11.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7100     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.00295  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 6.9      |
# |    value_loss         | 33.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7200     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.000868 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 9.34     |
# |    value_loss         | 77.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7300     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.00143  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 14.7     |
# |    value_loss         | 169      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7400     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.005    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 6.24     |
# |    value_loss         | 29.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7500     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -1.44    |
# |    explained_variance | 0.0025   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 9.71     |
# |    value_loss         | 84.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7600     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | -0.00442 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 6.35     |
# |    value_loss         | 89.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7700     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 154000   |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.00613 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 6.38     |
# |    value_loss         | 24.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7800     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 156000   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.00645  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 6.33     |
# |    value_loss         | 23.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 7900     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 158000   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.0128   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 5.49     |
# |    value_loss         | 22       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8000     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.00412  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 5.44     |
# |    value_loss         | 20.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8100     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 162000   |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.000112 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 4.74     |
# |    value_loss         | 19.3     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3064      |
# |    iterations         | 8200      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 164000    |
# | train/                |           |
# |    entropy_loss       | -1.28     |
# |    explained_variance | -4.11e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | 7.35      |
# |    value_loss         | 93        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8300     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 166000   |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.00379  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 4.13     |
# |    value_loss         | 16.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8400     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 6.75e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 3.15     |
# |    value_loss         | 9.79     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3064      |
# |    iterations         | 8500      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 170000    |
# | train/                |           |
# |    entropy_loss       | -1.23     |
# |    explained_variance | -5.25e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | 3.89      |
# |    value_loss         | 14.4      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8600     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 172000   |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.000708 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | 4.63     |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8700     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 174000   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.00418  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 3.94     |
# |    value_loss         | 12.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8800     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.0012  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | 4.34     |
# |    value_loss         | 11.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# |    iterations         | 8900     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 178000   |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.000241 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | 3.3      |
# |    value_loss         | 10.3     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3064      |
# |    iterations         | 9000      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 180000    |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -1.43e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | 3.71      |
# |    value_loss         | 23.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3064      |
# |    iterations         | 9100      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 182000    |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -0.000599 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 2.82      |
# |    value_loss         | 8.51      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3064      |
# |    iterations         | 9200      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 184000    |
# | train/                |           |
# |    entropy_loss       | -1.18     |
# |    explained_variance | -0.000205 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | 3.58      |
# |    value_loss         | 7.66      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3064     |
# ...
# |    time_elapsed       | 645      |
# |    total_timesteps    | 1940000  |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 4.01e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 96999    |
# |    policy_loss        | -5.64    |
# |    value_loss         | 35.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3006      |
# |    iterations         | 97100     |
# |    time_elapsed       | 645       |
# |    total_timesteps    | 1942000   |
# | train/                |           |
# |    entropy_loss       | -1.51     |
# |    explained_variance | -9.57e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97099     |
# |    policy_loss        | 4.3       |
# |    value_loss         | 67.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 97200    |
# |    time_elapsed       | 646      |
# |    total_timesteps    | 1944000  |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.527    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97199    |
# |    policy_loss        | -0.25    |
# |    value_loss         | 0.0388   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 97300    |
# |    time_elapsed       | 647      |
# |    total_timesteps    | 1946000  |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.000188 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97299    |
# |    policy_loss        | 4.59     |
# |    value_loss         | 115      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 97400    |
# |    time_elapsed       | 647      |
# |    total_timesteps    | 1948000  |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | -51.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97399    |
# |    policy_loss        | -0.648   |
# |    value_loss         | 0.0665   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 97500    |
# |    time_elapsed       | 648      |
# |    total_timesteps    | 1950000  |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -0.11    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97499    |
# |    policy_loss        | -0.304   |
# |    value_loss         | 0.0561   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 97600    |
# |    time_elapsed       | 649      |
# |    total_timesteps    | 1952000  |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | 0.0122   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97599    |
# |    policy_loss        | -0.281   |
# |    value_loss         | 0.0465   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 97700    |
# |    time_elapsed       | 649      |
# |    total_timesteps    | 1954000  |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | -1.7e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97699    |
# |    policy_loss        | -0.864   |
# |    value_loss         | 4.47     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3006      |
# |    iterations         | 97800     |
# |    time_elapsed       | 650       |
# |    total_timesteps    | 1956000   |
# | train/                |           |
# |    entropy_loss       | -1.52     |
# |    explained_variance | -0.000554 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97799     |
# |    policy_loss        | 12.3      |
# |    value_loss         | 118       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3006      |
# |    iterations         | 97900     |
# |    time_elapsed       | 651       |
# |    total_timesteps    | 1958000   |
# | train/                |           |
# |    entropy_loss       | -1.55     |
# |    explained_variance | -6.18e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97899     |
# |    policy_loss        | 2.13      |
# |    value_loss         | 39.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98000    |
# |    time_elapsed       | 651      |
# |    total_timesteps    | 1960000  |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | -0.025   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97999    |
# |    policy_loss        | -0.286   |
# |    value_loss         | 0.0576   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98100    |
# |    time_elapsed       | 652      |
# |    total_timesteps    | 1962000  |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.000754 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98099    |
# |    policy_loss        | 2.51     |
# |    value_loss         | 40.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98200    |
# |    time_elapsed       | 653      |
# |    total_timesteps    | 1964000  |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 3.61e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98199    |
# |    policy_loss        | 15.2     |
# |    value_loss         | 135      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98300    |
# |    time_elapsed       | 653      |
# |    total_timesteps    | 1966000  |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.00392  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98299    |
# |    policy_loss        | 0.172    |
# |    value_loss         | 2.95     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98400    |
# |    time_elapsed       | 654      |
# |    total_timesteps    | 1968000  |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | 0.00132  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98399    |
# |    policy_loss        | 12.3     |
# |    value_loss         | 67.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98500    |
# |    time_elapsed       | 655      |
# |    total_timesteps    | 1970000  |
# | train/                |          |
# |    entropy_loss       | -1.5     |
# |    explained_variance | 0.479    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98499    |
# |    policy_loss        | -0.21    |
# |    value_loss         | 0.0283   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98600    |
# |    time_elapsed       | 655      |
# |    total_timesteps    | 1972000  |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | -0.00175 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98599    |
# |    policy_loss        | -1.69    |
# |    value_loss         | 32.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98700    |
# |    time_elapsed       | 656      |
# |    total_timesteps    | 1974000  |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.0795   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98699    |
# |    policy_loss        | -0.237   |
# |    value_loss         | 0.032    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98800    |
# |    time_elapsed       | 657      |
# |    total_timesteps    | 1976000  |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | 0.0732   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98799    |
# |    policy_loss        | -0.253   |
# |    value_loss         | 0.0294   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 98900    |
# |    time_elapsed       | 657      |
# |    total_timesteps    | 1978000  |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | -0.315   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98899    |
# |    policy_loss        | -0.196   |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99000    |
# |    time_elapsed       | 658      |
# |    total_timesteps    | 1980000  |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 0.00556  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98999    |
# |    policy_loss        | -1.87    |
# |    value_loss         | 14.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3006      |
# |    iterations         | 99100     |
# |    time_elapsed       | 659       |
# |    total_timesteps    | 1982000   |
# | train/                |           |
# |    entropy_loss       | -1.5      |
# |    explained_variance | -6.79e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99099     |
# |    policy_loss        | 7.1       |
# |    value_loss         | 222       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99200    |
# |    time_elapsed       | 659      |
# |    total_timesteps    | 1984000  |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 3.3e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99199    |
# |    policy_loss        | 2.01     |
# |    value_loss         | 15.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99300    |
# |    time_elapsed       | 660      |
# |    total_timesteps    | 1986000  |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.532    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99299    |
# |    policy_loss        | -0.161   |
# |    value_loss         | 0.0176   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99400    |
# |    time_elapsed       | 661      |
# |    total_timesteps    | 1988000  |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | 0.0721   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99399    |
# |    policy_loss        | -0.187   |
# |    value_loss         | 0.0278   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99500    |
# |    time_elapsed       | 661      |
# |    total_timesteps    | 1990000  |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.000596 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99499    |
# |    policy_loss        | 0.845    |
# |    value_loss         | 35.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99600    |
# |    time_elapsed       | 662      |
# |    total_timesteps    | 1992000  |
# | train/                |          |
# |    entropy_loss       | -1.64    |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99599    |
# |    policy_loss        | -0.212   |
# |    value_loss         | 0.0256   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3006      |
# |    iterations         | 99700     |
# |    time_elapsed       | 663       |
# |    total_timesteps    | 1994000   |
# | train/                |           |
# |    entropy_loss       | -1.63     |
# |    explained_variance | -4.76e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99699     |
# |    policy_loss        | 0.608     |
# |    value_loss         | 13.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 99800    |
# |    time_elapsed       | 663      |
# |    total_timesteps    | 1996000  |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.114    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99799    |
# |    policy_loss        | -0.156   |
# |    value_loss         | 0.0145   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 3006      |
# |    iterations         | 99900     |
# |    time_elapsed       | 664       |
# |    total_timesteps    | 1998000   |
# | train/                |           |
# |    entropy_loss       | -1.63     |
# |    explained_variance | -2.74e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99899     |
# |    policy_loss        | 10.5      |
# |    value_loss         | 84.5      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 3006     |
# |    iterations         | 100000   |
# |    time_elapsed       | 665      |
# |    total_timesteps    | 2000000  |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 2.44e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99999    |
# |    policy_loss        | 5.03     |
# |    value_loss         | 157      |
# ------------------------------------

# %%
env = dilemma_v0.env('pd')

#env = ss.agent_indicator_v0(env)
rewards = []
env.reset()
for agent in env.agent_iter():
    obs, reward, done, info = env.last()
    rewards.append(reward)
    obs = obs.reshape(1,-1)
    act = model.predict(obs)[0] if not done else None
    env.step(act)
    env.render()
# Out:
# Delimma v2
# {'player_0': Box(-1, 1, (1, 4), int8), 'player_1': Box(-1, 1, (1, 4), int8), 'player_2': Box(-1, 1, (1, 4), int8), 'player_3': Box(-1, 1, (1, 4), int8)}
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 3, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 5, 'player_2': 3, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 0, 'player_1': 1, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, COOPERATE
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : COOPERATE, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# ...
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 1, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, COOPERATE
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : COOPERATE, player_3, COOPERATE
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 5, 'player_2': 5, 'player_3': 0}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 5, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_0, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, COOPERATE
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_2, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_3, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : COOPERATE, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 0, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : DEFECT, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 5, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_1, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_1, COOPERATE
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_2, DEFECT
# Current moves: player_1 : COOPERATE, player_0, DEFECT
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 0, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, COOPERATE
# Current moves: player_1 : COOPERATE, player_0, COOPERATE
# Current moves: player_2 : DEFECT, player_1, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 1, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_1, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : COOPERATE, player_1, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 3, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_2, COOPERATE
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_2, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_1, DEFECT
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 0, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, COOPERATE
# Current moves: player_2 : COOPERATE, player_2, COOPERATE
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 5}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_3, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_2, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 3, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_1, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# Current moves: player_0 : DEFECT, player_0, DEFECT
# Current moves: player_1 : DEFECT, player_3, DEFECT
# Current moves: player_2 : DEFECT, player_3, DEFECT
# Current moves: player_3 : DEFECT, player_0, DEFECT
# rewards {'player_0': 1, 'player_1': 1, 'player_2': 1, 'player_3': 1}
#
# rewards {}

# %%
model.predict(np.array([0,0,0,1]).reshape(1,-1))[0]
# Out:
# array([1, 2])

# %%
# Out:
# [0,
#  3,
#  0,
#  0,
#  15,
#  10,
#  16,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  4,
#  4,
#  4,
#  8,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  2,
#  8,
#  4,
#  8,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  8,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  8,
#  8,
#  0,
#  16,
#  16,
#  8,
#  0,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  1,
#  4,
#  4,
#  12,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  4,
#  4,
#  4,
#  10,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  12,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  1,
#  4,
#  4,
#  4,
#  3,
#  8,
#  4,
#  4,
#  4,
#  16,
#  4,
#  10,
#  4,
#  4,
#  4,
#  3,
#  12,
#  4,
#  4,
#  2,
#  20,
#  4,
#  4,
#  4,
#  12,
#  8,
#  4,
#  1,
#  4,
#  12,
#  3,
#  7,
#  4,
#  16,
#  0,
#  16,
#  16,
#  4,
#  4,
#  4,
#  12,
#  4,
#  4,
#  4,
#  4,
#  8,
#  2,
#  8,
#  4,
#  20,
#  8,
#  4,
#  4,
#  15,
#  16,
#  10,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  4,
#  4,
#  4,
#  10,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  1,
#  4,
#  4,
#  4,
#  0,
#  4,
#  4,
#  4,
#  0,
#  4,
#  8,
#  4,
#  0,
#  8,
#  10,
#  8,
#  2,
#  18,
#  1,
#  6,
#  4,
#  10,
#  4,
#  10,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  5,
#  4,
#  4,
#  16,
#  6,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  8,
#  4,
#  4,
#  1,
#  4,
#  4,
#  3,
#  8,
#  4,
#  4,
#  1,
#  4,
#  8,
#  4,
#  4,
#  0,
#  8,
#  4,
#  16,
#  4,
#  4,
#  4,
#  8,
#  4,
#  4,
#  0,
#  16,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  8,
#  4,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  8,
#  3,
#  16,
#  4,
#  16,
#  8,
#  4,
#  4,
#  3,
#  8,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  8,
#  4,
#  0,
#  20,
#  16,
#  1,
#  1,
#  16,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  16,
#  4,
#  1,
#  0,
#  16,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  4,
#  4,
#  4,
#  10,
#  2,
#  4,
#  4,
#  16,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  2,
#  4,
#  12,
#  12,
#  1,
#  4,
#  3,
#  12,
#  2,
#  4,
#  0,
#  16,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  8,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  3,
#  6,
#  16,
#  4,
#  1,
#  6,
#  20,
#  4,
#  4,
#  4,
#  20,
#  4,
#  4,
#  4,
#  20,
#  4,
#  4,
#  4,
#  20,
#  4,
#  4,
#  4,
#  20,
#  8,
#  4,
#  4,
#  0,
#  16,
#  4,
#  4,
#  0,
#  4,
#  4,
#  3,
#  12,
#  4,
#  4,
#  1,
#  20,
#  4,
#  4,
#  4,
#  12,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  8,
#  0,
#  16,
#  4,
#  16,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  12,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  16,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  2,
#  4,
#  4,
#  12,
#  0,
#  4,
#  4,
#  4,
#  2,
#  3,
#  4,
#  12,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  8,
#  0,
#  16,
#  16,
#  16,
#  4,
#  8,
#  4,
#  1,
#  8,
#  16,
#  4,
#  0,
#  4,
#  12,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  4,
#  3,
#  16,
#  4,
#  4,
#  10,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  4,
#  0,
#  16,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  4,
#  0,
#  16,
#  12,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  8,
#  4,
#  1,
#  4,
#  4,
#  4,
#  8,
#  8,
#  4,
#  4,
#  16,
#  16,
#  10,
#  4,
#  3,
#  8,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  1,
#  4,
#  16,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  16,
#  4,
#  4,
#  4,
#  20,
#  4,
#  4,
#  4,
#  8,
#  3,
#  8,
#  4,
#  4,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  12,
#  8,
#  3,
#  6,
#  0,
#  16,
#  1,
#  4,
#  0,
#  4,
#  4,
#  4,
#  0,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  2,
#  4,
#  12,
#  16,
#  3,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  12,
#  2,
#  4,
#  1,
#  16,
#  1,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  8,
#  4,
#  ...]

# %%
import sys
sys.path.append('../')

from pettingzoo.test import parallel_api_test
from src.environments import simple_pd_v0

env = dilemma_v0.env()
env = to_parallel(env)

parallel_api_test(env, num_cycles=1)

# %%
env = dilemma_v0.env('sd')

#env = ss.agent_indicator_v0(env)
rewards = []
env.reset()

# %%
obs, reward, done, info = env.last()
print(obs, reward, done, info)
rewards.append(reward)
act = model.predict(2)[0] if not done else None
env.step(1)
env.render()
# Out:
# 1 1 False {}
# Current state: Agent1: ANTI_SOCIAL , Agent2: ANTI_SOCIAL
# {'player_0': 1, 'player_1': 1}

# %%
[0 for n in range(5)]
# Out:
# [0, 0, 0, 0, 0]

# %%
np.zeros(4)
# Out:
# array([0., 0., 0., 0.])
